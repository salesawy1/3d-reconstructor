# %%
# Install Miniconda
# !wget -c https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local

# Initialize Conda
# !/usr/local/bin/conda init
# Out:
# --2024-09-29 06:44:54--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 148981743 (142M) [application/octet-stream]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>] 142.08M   214MB/s    in 0.7s
#
# 2024-09-29 06:44:55 (214 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [148981743/148981743]
#
# PREFIX=/usr/local
# Unpacking payload ...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
# ...

# %%
# @title
# !sudo ln -s /opt/conda/root/etc/profile.d/conda.sh /etc/profile.d/conda.s

# %%
# !eval "$(/usr/local/condabin/conda shell.bash hook)"

# %%
# !git clone --recursive https://github.com/naver/dust3r
# Out:
# Cloning into 'dust3r'...
# remote: Enumerating objects: 550, done.
# remote: Counting objects: 100% (330/330), done.
# remote: Compressing objects: 100% (193/193), done.
# remote: Total 550 (delta 226), reused 140 (delta 137), pack-reused 220 (from 1)
# Receiving objects: 100% (550/550), 740.55 KiB | 2.18 MiB/s, done.
# Resolving deltas: 100% (318/318), done.
# Submodule 'croco' (https://github.com/naver/croco) registered for path 'croco'
# Cloning into '/content/dust3r/croco'...
# remote: Enumerating objects: 124, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 124 (delta 26), reused 21 (delta 21), pack-reused 90 (from 1)
# Receiving objects: 100% (124/124), 385.05 KiB | 1.14 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# Submodule path 'croco': checked out '743ee71a2a9bf57cea6832a9064a70a0597fcfcb'

# %%
# %cd dust3r
# Out:
# /content/dust3r

# %%
# !conda create -n dust3r python=3.11 cmake=3.14.0
# Out:
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/dust3r
#
#   added / updated specs:
#     - cmake=3.14.0
#     - python=3.11
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cmake-3.14.0               |       h52cb24c_0         5.5 MB
#     expat-2.6.3                |       h6a678d5_0         176 KB
#     ld_impl_linux-64-2.40      |       h12ee557_0         710 KB
#     libcurl-8.9.1              |       h251f7ec_0         439 KB
#     openssl-3.0.15             |       h5eee18b_0         5.2 MB
#     pip-24.2                   |  py311h06a4308_0         2.8 MB
#     python-3.11.9              |       h955ad1f_0        32.9 MB
#     rhash-1.4.3                |       hdbd6064_0         220 KB
#     setuptools-75.1.0          |  py311h06a4308_0         2.2 MB
# ...

# %%
# %%shell
# eval "$(conda shell.bash hook)" # copy conda command to shell
# conda activate dust3r
# python --version
# Out:
# Python 3.11.9

# %%
# !conda install pytorch torchvision pytorch-cuda=12.1 -c pytorch -c nvidia
# Out:
# Channels:
#  - pytorch
#  - nvidia
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - pytorch
#     - pytorch-cuda=12.1
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |              mkl           6 KB
#     certifi-2024.8.30          |  py312h06a4308_0         163 KB
#     cuda-cudart-12.1.105       |                0         189 KB  nvidia
#     cuda-cupti-12.1.105        |                0        15.4 MB  nvidia
#     cuda-libraries-12.1.0      |                0           2 KB  nvidia
#     cuda-nvrtc-12.1.105        |                0        19.7 MB  nvidia
#     cuda-nvtx-12.1.105         |                0          57 KB  nvidia
#     cuda-opencl-12.6.68        |                0          26 KB  nvidia
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# ...
#   Using cached einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
# ...
#   Using cached typer-0.12.5-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# ...
#   Using cached six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# ...
#   Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# ...
#   Using cached werkzeug-3.0.4-py3-none-any.whl.metadata (3.7 kB)
# ...
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# ...

# %%
# !mkdir -p checkpoints/

# %%
# !pip install opencv-python
# !pip install trimesh

# %%
# !wget https://download.europe.naverlabs.com/ComputerVision/DUSt3R/DUSt3R_ViTLarge_BaseDecoder_512_dpt.pth -P checkpoints/
# Out:
# --2024-09-29 06:52:27--  https://download.europe.naverlabs.com/ComputerVision/DUSt3R/DUSt3R_ViTLarge_BaseDecoder_512_dpt.pth
# Resolving download.europe.naverlabs.com (download.europe.naverlabs.com)... 110.234.56.25
# Connecting to download.europe.naverlabs.com (download.europe.naverlabs.com)|110.234.56.25|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2285005731 (2.1G)
# Saving to: ‘checkpoints/DUSt3R_ViTLarge_BaseDecoder_512_dpt.pth’
#
# DUSt3R_ViTLarge_Bas 100%[===================>]   2.13G  24.5MB/s    in 96s
#
# 2024-09-29 06:54:04 (22.7 MB/s) - ‘checkpoints/DUSt3R_ViTLarge_BaseDecoder_512_dpt.pth’ saved [2285005731/2285005731]

# %%
# !python3 export_batches.py --model_name DUSt3R_ViTLarge_BaseDecoder_512_dpt --video_in "/content/drive/MyDrive/ngp_mhacks/hat_flip"
# Out:
# Warning, cannot find cuda-compiled version of RoPE2D, using a slow pytorch version instead
# /content/dust3r/dust3r/cloud_opt/base_opt.py:275: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# [2024-09-29 08:48:07] Outputing stuff in /tmp/tmpuoq6a9m9dust3r_gradio_demo
# [2024-09-29 08:48:07] Removed directory and contents: /content/data/temp/
# [2024-09-29 08:48:19] Frame extraction complete.
# [2024-09-29 08:48:19] Entering batch generate...
# [2024-09-29 08:48:19] Reconstructing Scene...
# [2024-09-29 08:48:19] >> Loading images from /content/data/temp/batch_0
# [2024-09-29 08:48:19]  - adding nathan_computer_batch_0.jpg with resolution 1280x720 --> 512x288
# [2024-09-29 08:48:19]  - adding nathan_phone_batch_0.jpg with resolution 720x1280 --> 288x512
# [2024-09-29 08:48:19]  - adding patrick-computer_batch_0.jpg with resolution 1920x1080 --> 512x288
# ...

# %%
# !python3 demo.py --model_name DUSt3R_ViTLarge_BaseDecoder_512_dpt
# Out:
# Warning, cannot find cuda-compiled version of RoPE2D, using a slow pytorch version instead
# /content/dust3r/dust3r/cloud_opt/base_opt.py:275: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# [2024-09-29 08:41:22] Outputing stuff in /tmp/tmpa861cuxtdust3r_gradio_demo
# t=2024-09-29T08:41:22+0000 lvl=warn msg="failed to get home directory, using $HOME instead" err="user: Current requires cgo or $USER set in environment" $HOME=/root
# [2024-09-29 08:41:23] Public URL: NgrokTunnel: "https://0f6c-34-16-147-169.ngrok-free.app" -> "http://localhost:7860"
# [2024-09-29 08:41:23] Running on local URL:  http://127.0.0.1:7860
# [2024-09-29 08:41:23]
# To create a public link, set `share=True` in `launch()`.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/site-packages/gradio/blocks.py", line 2710, in block_thread
#     time.sleep(0.1)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd dust3r
# Out:
# [Errno 2] No such file or directory: 'dust3r'
# /content

# %%
# !pip install torch gradio pyngrok matplotlib

# %%
# !ngrok authtoken 2SmDEnKIDmvQsAgRmqU0JZnVD25_7tVXirnyigzEw6iBszLBV
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
